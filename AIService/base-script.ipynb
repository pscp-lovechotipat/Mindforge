# %%
# Cell 1: Imports and Setup
from typing import Dict, List, Any, Optional
import tempfile
import os
import shutil
from collections import defaultdict
import json

from module.agent_document_summarize import process_documents
from module.agent_human_management import analyze_team_roles, validate_team_details
from module.graph_updates import Neo4jCRUD
from module.get_model_and_embeding import get_llm

# Neo4j configuration
NEO4J_URI = "neo4j://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "neo4j123"

# Cell 2: Helper Functions
def save_files_to_temp(file_paths: List[str]) -> tuple[List[str], str]:
    """Save files to temporary directory"""
    temp_dir = tempfile.mkdtemp()
    temp_paths = []
    
    for file_path in file_paths:
        if not file_path.lower().endswith(('.pdf', '.txt', '.md')):
            raise ValueError(f"Unsupported file type: {file_path}")
        
        file_name = os.path.basename(file_path)
        temp_path = os.path.join(temp_dir, file_name)
        shutil.copy2(file_path, temp_path)
        temp_paths.append(temp_path)
    
    return temp_paths, temp_dir

def distribute_tasks(db: Neo4jCRUD, workspace_id: str) -> Dict[str, List[Dict[str, Any]]]:
    """Distribute tasks evenly among team members"""
    with db.driver.session(database=workspace_id) as session:
        # Get all tasks and their associated roles
        result = session.run("""
            MATCH (w:Workspace {name: $workspace})-[:CONTAINS_ROLE]->(r:Role)-[:HAS_TASK]->(t:Task)
            MATCH (p:Person)-[:CAN_PERFORM]->(r)
            RETURN p.name as person, r.name as role, t.name as task, ID(t) as task_id
        """, workspace=workspace_id)
        
        # Organize tasks by person
        tasks_by_person = defaultdict(list)
        for record in result:
            person = record["person"]
            tasks_by_person[person].append({
                "task": record["task"],
                "role": record["role"],
                "node_id": record["task_id"]
            })
            
        return dict(tasks_by_person)

# Cell 3: Neo4j Graph Creation Function
def create_neo4j_graph(
    workspace_id: str,
    document_analysis: Dict[str, List[str]],
    team_analysis: Dict[str, List[str]]
) -> None:
    """Create Neo4j graph with relationships"""
    db = Neo4jCRUD(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD, workspace_id)
    
    try:
        # Create workspace node
        db.create_node("Workspace", {"name": workspace_id})
        print(f"Created workspace node: {workspace_id}")
        
        # Process roles and tasks from document analysis
        for role, tasks in document_analysis.items():
            if role != "_processing_summary":
                # Create role node
                db.create_node("Role", {
                    "name": role,
                    "type": "role"
                })
                print(f"Created role node: {role}")
                
                # Link role to workspace
                db.create_relationship(
                    "Workspace", workspace_id,
                    "Role", role,
                    "CONTAINS_ROLE"
                )
                
                # Create task nodes and link to role
                for task in tasks:
                    db.create_node("Task", {
                        "name": task,
                        "type": "task"
                    })
                    db.create_relationship(
                        "Role", role,
                        "Task", task,
                        "HAS_TASK"
                    )
                print(f"Created {len(tasks)} tasks for role: {role}")
        
        # Process team members and their possible roles
        for member_name, possible_roles in team_analysis.items():
            # Create team member node
            db.create_node("Person", {
                "name": member_name,
                "type": "person"
            })
            print(f"Created person node: {member_name}")
            
            # Link member to workspace
            db.create_relationship(
                "Workspace", workspace_id,
                "Person", member_name,
                "HAS_MEMBER"
            )
            
            # Link member to possible roles
            for role in possible_roles:
                if role in document_analysis:
                    db.create_relationship(
                        "Person", member_name,
                        "Role", role,
                        "CAN_PERFORM"
                    )
            print(f"Created {len(possible_roles)} role relationships for: {member_name}")
    
    finally:
        db.close()

# Cell 4: Main Processing Function
def process_and_store(
    workspace_id: str,
    file_paths: List[str],
    team_details: Dict[str, Dict[str, Any]]
) -> Dict[str, Any]:
    """Process documents and team analysis, storing results in Neo4j"""
    try:
        # Validate team details
        validate_team_details(team_details)
        print("Team details validated")
        
        # Save files to temp directory
        temp_paths, temp_dir = save_files_to_temp(file_paths)
        print(f"Files saved to temporary directory: {temp_dir}")
        
        try:
            # Initialize LLM
            llm = get_llm()
            print("LLM initialized")
            
            # Process documents
            document_analysis = process_documents(
                document_paths=temp_paths,
                current_roles=[details["current_role"] for details in team_details.values()]
            )
            print("Document analysis completed")
            
            # Analyze team roles
            team_analysis = analyze_team_roles(team_details, llm)
            print("Team role analysis completed")
            
            # Create Neo4j graph
            create_neo4j_graph(workspace_id, document_analysis, team_analysis)
            print("Neo4j graph created")
            
            return {
                "status": "success",
                "document_analysis": document_analysis,
                "team_analysis": team_analysis
            }
            
        finally:
            shutil.rmtree(temp_dir)
            print("Temporary directory cleaned up")
            
    except Exception as e:
        print(f"Error in processing: {str(e)}")
        raise

# Cell 5: Graph Management Functions
def delete_node(workspace_id: str, node_id: str, node_name: str) -> Dict[str, str]:
    """Delete a node from the graph"""
    db = Neo4jCRUD(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD, workspace_id)
    try:
        with db.driver.session(database=workspace_id) as session:
            session.run("""
                MATCH (n)
                WHERE ID(n) = $node_id AND n.name = $node_name
                DETACH DELETE n
            """, node_id=int(node_id), node_name=node_name)
            
        return {"status": "success", "message": f"Node {node_name} deleted"}
    finally:
        db.close()

def update_node(
    workspace_id: str,
    node_id: str,
    node_name: str,
    new_properties: Dict[str, Any]
) -> Dict[str, str]:
    """Update a node's properties"""
    db = Neo4jCRUD(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD, workspace_id)
    try:
        with db.driver.session(database=workspace_id) as session:
            session.run("""
                MATCH (n)
                WHERE ID(n) = $node_id AND n.name = $node_name
                SET n += $properties
            """, 
                node_id=int(node_id),
                node_name=node_name,
                properties=new_properties
            )
        return {"status": "success", "message": f"Node {node_name} updated"}
    finally:
        db.close()

def get_workspace_tasks(workspace_id: str) -> Dict[str, List[Dict[str, Any]]]:
    """Get distributed tasks for a workspace"""
    db = Neo4jCRUD(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD, workspace_id)
    try:
        return distribute_tasks(db, workspace_id)
    finally:
        db.close()

# %%
# Test data
test_workspace = "wakuwakuanya"

# Sample team details
test_team = {
    "John Doe": {
        "current_role": "Software Developer",
        "skills": ["Python", "JavaScript", "Docker"],
        "experience": "5 years in web development"
    },
    "Jane Smith": {
        "current_role": "UX Designer",
        "skills": ["UI/UX Design", "Figma", "User Research"],
        "experience": "3 years in product design"
    }
}

# Sample document paths
test_docs = [
    r"D:\Mindforge\AIService\test_doc\doc1.pdf"
]

# %%
# Process documents and create graph
print("Starting processing...")
result = process_and_store(test_workspace, test_docs, test_team)
print("\nProcessing result:", json.dumps(result, indent=2))
# Out:
# Starting processing...
# Team details validated
# Files saved to temporary directory: C:\Users\Tanap\AppData\Local\Temp\tmpzjoll9wp
# LLM initialized
# Loading documents from 1 paths...
# Loading documents...
# Loaded 27 documents.
# Loaded 27 documents successfully.
#
# Processing document 1/27...
# Successfully processed document 1
#
# Processing document 2/27...
# Successfully processed document 2
#
# Processing document 3/27...
# Successfully processed document 3
#
# Processing document 4/27...
# Successfully processed document 4
#
# Processing document 5/27...
# Successfully processed document 5
#
# Processing document 6/27...
# Successfully processed document 6
#
# Processing document 7/27...
# Successfully processed document 7
#
# Processing document 8/27...
# Successfully processed document 8
#
# Processing document 9/27...
# Successfully processed document 9
#
# Processing document 10/27...
# Successfully processed document 10
#
# Processing document 11/27...
# Successfully processed document 11
#
# Processing document 12/27...
# Successfully processed document 12
#
# Processing document 13/27...
# Successfully processed document 13
#
# Processing document 14/27...
# Successfully processed document 14
#
# Processing document 15/27...
# Successfully processed document 15
#
# Processing document 16/27...
# Successfully processed document 16
#
# Processing document 17/27...
# Successfully processed document 17
#
# Processing document 18/27...
# Successfully processed document 18
#
# Processing document 19/27...
# Successfully processed document 19
#
# Processing document 20/27...
# Successfully processed document 20
#
# Processing document 21/27...
# Successfully processed document 21
#
# Processing document 22/27...
# Successfully processed document 22
#
# Processing document 23/27...
# Successfully processed document 23
#
# Processing document 24/27...
# Successfully processed document 24
#
# Processing document 25/27...
# Successfully processed document 25
#
# Processing document 26/27...
# Successfully processed document 26
#
# Processing document 27/27...
# Successfully processed document 27
# Document analysis completed
# Analyzing roles for team member: John Doe
# Successfully analyzed roles for John Doe
# Analyzing roles for team member: Jane Smith
# Successfully analyzed roles for Jane Smith
# Team role analysis completed
# Created workspace node: wakuwakuanya
# Created role node: Software Developer
# Created 133 tasks for role: Software Developer
# Created role node: UX Designer
# Created 17 tasks for role: UX Designer
# Created role node: Reviewer
# Created 3 tasks for role: Reviewer
# Created role node: Tester
# Created 6 tasks for role: Tester
# Created person node: John Doe
# Created 8 role relationships for: John Doe
# Created person node: Jane Smith
# Created 8 role relationships for: Jane Smith
# Neo4j graph created
# Temporary directory cleaned up
#
# Processing result: {
#   "status": "success",
#   "document_analysis": {
#     "Software Developer": [
#       "Identify the relationships among classes",
#       "Estimate testing activities",
#       "solve problems",
#       "test code",
#       "Test the complete system against initial requirements",
#       "Attempt to quantify software projects by using the size of the project to normalize other quality measures",
#       "Implement software",
#       "Participate in object-oriented analysis process",
#       "Design and implement modules with high functional cohesion and low coupling",
#       "reuse existing prototypes to build the actual system",
#       "troubleshooting",
#       "Describe the interfaces and interactions of the modules",
#       "Split up the software into its components",
#       "Define the functional contents of the modules",
#       "testing",
#       "produce working software",
#       "integrate all the available prototypes to form a complete system",
#       "Generate a Software Design Document",
#       "Check if all requirements are finalized",
#       "develop the system",
#       "Identify objects and group into classes",
#       "Develop systems that cannot be tampered by other parts of the system",
#       "complete a defined task",
#       "Developing the initial Prototype",
#       "Specify optimization criteria",
#       "accommodate changing requirements",
#       "Create dummy functions to act in place of other functions for testing",
#       "installation",
#       "build a prototype",
#       "Generate a System Architecture Document",
#       "Develop units independently",
#       "Review glossary",
#       "Maintenance",
#       "simulate data processing using a prototype services layer",
#       "Describe the various types of Coupling and Cohesion",
#       "release patches",
#       "transfer abstract of the program into code",
#       "concept",
#       "perform maintenance",
#       "Build from high-level models or concepts to lower-level details",
#       "Check requirements for validity and the possibility to implement them",
#       "Establish or update work products in each of the activities",
#       "implement and integrate services to the final prototype",
#       "develop a system",
#       "evaluate developer proposals and try them out before implementation",
#       "Decide whether to use prototyping based on the level of user interactions in the system",
#       "Define the operations that should be performed on the classes",
#       "Manage software complexity",
#       "Solve problems that did not arise during previous phases",
#       "Identify events and analyze the applicability of actions",
#       "Carry out activities in each of the sub-phases",
#       "Track and run the project",
#       "design system",
#       "Revise and enhance the Prototype",
#       "understand customer requirements",
#       "write code",
#       "Analyse the needs of the end user(s)",
#       "operation and maintenance",
#       "Use software estimation techniques for project estimation",
#       "Implement forward engineering principles in software development",
#       "Requirement Gathering and analysis",
#       "Create user object model diagram",
#       "deliver changes in the customer environment",
#       "Construct data \ufb02ow diagrams showing functional dependencies",
#       "Identify all the inputs and outputs",
#       "Test the product",
#       "Fix changes necessary to make the system usable or comply to customer wishes",
#       "Set up the de\ufb01ned modules or units",
#       "Validate the state\u2013transition diagrams drawn",
#       "Identify and analyze different types of cohesion",
#       "Add to the possible knowledge base of test estimation methods and estimation templates",
#       "add functionality",
#       "analyze specifications",
#       "Identify relationships among classes",
#       "Build a prototype to give the exact look and feel even before the actual software is developed",
#       "Design the system",
#       "Determine system requirements",
#       "measure progress within stages",
#       "Deployment of system",
#       "understand about what exactly is expected from the product under development",
#       "complete development time",
#       "Requirement Analysis and Speci\ufb01cation",
#       "Organize elements of module such that they are processed at a similar point in time",
#       "Consider all necessary system states",
#       "Integrate units into a complete system",
#       "detect defects",
#       "get valuable feedback from the customer",
#       "Develop a fully functional UI with very little regard to the actual services",
#       "Measure the quality of a design of modules and their interaction among them",
#       "Implementation",
#       "Feasibility Study",
#       "Identify states of each object",
#       "Identify the types of cohesion",
#       "Break the program into smaller modules for the sake of modularization",
#       "Integration and Testing",
#       "Check if required infrastructure is ready for testing",
#       "Define the software components to meet the end user requirements and to meet the need of possible scalability of the system",
#       "design",
#       "Express each state in terms of object attributes",
#       "Identify which objects would generate an optimal system design",
#       "build multiple functional prototypes of the various sub systems",
#       "Collect requirements of the system",
#       "implementation",
#       "Break down software blocks into code modules",
#       "communication requirement analysis",
#       "develop software",
#       "Collect data: number of lines of code, number of person-months to complete, cost of the project, number of pages of documentation, number of errors corrected before release, number of bugs found post release",
#       "Develop the product",
#       "design modeling",
#       "Generate a software architecture document",
#       "Define the activity and behaviour of the software",
#       "Start actual coding",
#       "release better versions",
#       "build software application prototypes",
#       "fix issues",
#       "Use process models to describe the sequence of phases for the entire lifetime of a product",
#       "Develop static structure of the software system in terms of objects",
#       "developing the software",
#       "functional decomposition",
#       "design a software prototype",
#       "program construction testing and support",
#       "enhance the product",
#       "System Design",
#       "Test units for functionality",
#       "Identify constraints",
#       "State the purpose of each function",
#       "Document all assumptions and risks",
#       "Define user object attributes",
#       "Generate a Requirements Speci\ufb01cation Document",
#       "Determine the degree of intra-dependability within elements of a module",
#       "Identify classes",
#       "Determine the level of coupling among modules",
#       "Construct dynamic model diagram, comprising of state transition diagrams"
#     ],
#     "UX Designer": [
#       "identify confusing or difficult functions",
#       "understand about what exactly is expected from the product under development",
#       "Check requirements for validity and the possibility to implement them",
#       "Generate a Requirements Speci\ufb01cation Document",
#       "Provide a better understanding of the system to users through a working model",
#       "Basic Requirement Identi\ufb01cation",
#       "understand customer requirements",
#       "Review of the Prototype",
#       "design a software prototype",
#       "Increase user involvement in the product even before implementation",
#       "Create a working model of the system to display to users",
#       "Analyse the needs of the end user(s)",
#       "evaluate developer proposals and try them out before implementation",
#       "Design the system",
#       "Define the software components to meet the end user requirements and to meet the need of possible scalability of the system",
#       "design the system",
#       "gather user feedback"
#     ],
#     "Reviewer": [
#       "Detect defects",
#       "Perform design review",
#       "Verify and validate design outputs"
#     ],
#     "Tester": [
#       "calculate test estimation techniques",
#       "use past data/past experience",
#       "use available documents/knowledge",
#       "make assumptions",
#       "calculate risks",
#       "estimate"
#     ],
#     "_processing_summary": {
#       "total_documents": 27,
#       "successful_documents": 27,
#       "failed_documents": 0,
#       "settings": {
#         "model": "llama-3.1-70b-versatile",
#         "temperature": 0.3,
#         "request_delay": 1.0,
#         "max_retries": 3
#       }
#     }
#   },
#   "team_analysis": {
#     "John Doe": [
#       "Software Developer",
#       "DevOps Engineer",
#       "Full Stack Developer",
#       "Backend Developer",
#       "Cloud Engineer",
#       "Technical Lead",
#       "Web Developer",
#       "Cloud Architect"
#     ],
#     "Jane Smith": [
#       "UX Designer",
#       "UI Designer",
#       "User Experience Researcher",
#       "Product Designer",
#       "Interaction Designer",
#       "Visual Designer",
#       "Design Consultant",
#       "Human-Computer Interaction Specialist"
#     ]
#   }
# }

# %%
# Get distributed tasks
print("\nRetrieving tasks...")
tasks = get_workspace_tasks(test_workspace)
print("Task distribution:", json.dumps(tasks, indent=2))
# Out:
# Retrieving tasks...
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 4, column: 70, offset: 219} for query: '\n            MATCH (w:Workspace {name: $workspace})-[:CONTAINS_ROLE]->(r:Role)-[:HAS_TASK]->(t:Task)\n            MATCH (p:Person)-[:CAN_PERFORM]->(r)\n            RETURN p.name as person, r.name as role, t.name as task, ID(t) as task_id\n        '
# Task distribution: {
#   "John Doe": [
#     {
#       "task": "Identify events and analyze the applicability of actions",
#       "role": "Software Developer",
#       "node_id": 51
#     },
#     {
#       "task": "Construct dynamic model diagram, comprising of state transition diagrams",
#       "role": "Software Developer",
#       "node_id": 134
#     },
#     {
#       "task": "Determine the level of coupling among modules",
#       "role": "Software Developer",
#       "node_id": 133
#     },
#     {
#       "task": "Identify classes",
#       "role": "Software Developer",
#       "node_id": 132
#     },
#     {
#       "task": "Determine the degree of intra-dependability within elements of a module",
#       "role": "Software Developer",
#       "node_id": 131
#     },
#     {
#       "task": "Generate a Requirements Speci\ufb01cation Document",
#       "role": "Software Developer",
#       "node_id": 130
#     },
#     {
#       "task": "Define user object attributes",
#       "role": "Software Developer",
#       "node_id": 129
#     },
#     {
#       "task": "Document all assumptions and risks",
#       "role": "Software Developer",
#       "node_id": 128
#     },
#     {
#       "task": "State the purpose of each function",
#       "role": "Software Developer",
#       "node_id": 127
#     },
#     {
#       "task": "Identify constraints",
#       "role": "Software Developer",
#       "node_id": 126
#     },
#     {
#       "task": "Test units for functionality",
#       "role": "Software Developer",
#       "node_id": 125
#     },
#     {
#       "task": "System Design",
#       "role": "Software Developer",
#       "node_id": 124
#     },
#     {
#       "task": "enhance the product",
#       "role": "Software Developer",
#       "node_id": 123
#     },
#     {
#       "task": "program construction testing and support",
#       "role": "Software Developer",
#       "node_id": 122
#     },
#     {
#       "task": "design a software prototype",
#       "role": "Software Developer",
#       "node_id": 121
#     },
#     {
#       "task": "functional decomposition",
#       "role": "Software Developer",
#       "node_id": 120
#     },
#     {
#       "task": "developing the software",
#       "role": "Software Developer",
#       "node_id": 119
#     },
#     {
#       "task": "Develop static structure of the software system in terms of objects",
#       "role": "Software Developer",
#       "node_id": 118
#     },
#     {
#       "task": "Use process models to describe the sequence of phases for the entire lifetime of a product",
#       "role": "Software Developer",
#       "node_id": 117
#     },
#     {
#       "task": "fix issues",
#       "role": "Software Developer",
#       "node_id": 116
#     },
#     {
#       "task": "build software application prototypes",
#       "role": "Software Developer",
#       "node_id": 115
#     },
#     {
#       "task": "release better versions",
#       "role": "Software Developer",
#       "node_id": 114
#     },
#     {
#       "task": "Start actual coding",
#       "role": "Software Developer",
#       "node_id": 113
#     },
#     {
#       "task": "Define the activity and behaviour of the software",
#       "role": "Software Developer",
#       "node_id": 112
#     },
#     {
#       "task": "Generate a software architecture document",
#       "role": "Software Developer",
#       "node_id": 111
#     },
#     {
#       "task": "design modeling",
#       "role": "Software Developer",
#       "node_id": 110
#     },
#     {
#       "task": "Develop the product",
#       "role": "Software Developer",
#       "node_id": 109
#     },
#     {
#       "task": "Collect data: number of lines of code, number of person-months to complete, cost of the project, number of pages of documentation, number of errors corrected before release, number of bugs found post release",
#       "role": "Software Developer",
#       "node_id": 108
#     },
#     {
#       "task": "develop software",
#       "role": "Software Developer",
#       "node_id": 107
#     },
#     {
#       "task": "communication requirement analysis",
#       "role": "Software Developer",
#       "node_id": 106
#     },
#     {
#       "task": "Break down software blocks into code modules",
#       "role": "Software Developer",
#       "node_id": 105
#     },
#     {
#       "task": "implementation",
#       "role": "Software Developer",
#       "node_id": 104
#     },
#     {
#       "task": "Collect requirements of the system",
#       "role": "Software Developer",
#       "node_id": 103
#     },
#     {
#       "task": "build multiple functional prototypes of the various sub systems",
#       "role": "Software Developer",
#       "node_id": 102
#     },
#     {
#       "task": "Identify which objects would generate an optimal system design",
#       "role": "Software Developer",
#       "node_id": 101
#     },
#     {
#       "task": "Express each state in terms of object attributes",
#       "role": "Software Developer",
#       "node_id": 100
#     },
#     {
#       "task": "design",
#       "role": "Software Developer",
#       "node_id": 99
#     },
#     {
#       "task": "Define the software components to meet the end user requirements and to meet the need of possible scalability of the system",
#       "role": "Software Developer",
#       "node_id": 98
#     },
#     {
#       "task": "Check if required infrastructure is ready for testing",
#       "role": "Software Developer",
#       "node_id": 97
#     },
#     {
#       "task": "Integration and Testing",
#       "role": "Software Developer",
#       "node_id": 96
#     },
#     {
#       "task": "Break the program into smaller modules for the sake of modularization",
#       "role": "Software Developer",
#       "node_id": 95
#     },
#     {
#       "task": "Identify the types of cohesion",
#       "role": "Software Developer",
#       "node_id": 94
#     },
#     {
#       "task": "Identify states of each object",
#       "role": "Software Developer",
#       "node_id": 93
#     },
#     {
#       "task": "Feasibility Study",
#       "role": "Software Developer",
#       "node_id": 92
#     },
#     {
#       "task": "Implementation",
#       "role": "Software Developer",
#       "node_id": 91
#     },
#     {
#       "task": "Measure the quality of a design of modules and their interaction among them",
#       "role": "Software Developer",
#       "node_id": 90
#     },
#     {
#       "task": "Develop a fully functional UI with very little regard to the actual services",
#       "role": "Software Developer",
#       "node_id": 89
#     },
#     {
#       "task": "get valuable feedback from the customer",
#       "role": "Software Developer",
#       "node_id": 88
#     },
#     {
#       "task": "detect defects",
#       "role": "Software Developer",
#       "node_id": 87
#     },
#     {
#       "task": "Integrate units into a complete system",
#       "role": "Software Developer",
#       "node_id": 86
#     },
#     {
#       "task": "Consider all necessary system states",
#       "role": "Software Developer",
#       "node_id": 85
#     },
#     {
#       "task": "Organize elements of module such that they are processed at a similar point in time",
#       "role": "Software Developer",
#       "node_id": 84
#     },
#     {
#       "task": "Requirement Analysis and Speci\ufb01cation",
#       "role": "Software Developer",
#       "node_id": 83
#     },
#     {
#       "task": "complete development time",
#       "role": "Software Developer",
#       "node_id": 82
#     },
#     {
#       "task": "understand about what exactly is expected from the product under development",
#       "role": "Software Developer",
#       "node_id": 81
#     },
#     {
#       "task": "Deployment of system",
#       "role": "Software Developer",
#       "node_id": 80
#     },
#     {
#       "task": "measure progress within stages",
#       "role": "Software Developer",
#       "node_id": 79
#     },
#     {
#       "task": "Determine system requirements",
#       "role": "Software Developer",
#       "node_id": 78
#     },
#     {
#       "task": "Design the system",
#       "role": "Software Developer",
#       "node_id": 77
#     },
#     {
#       "task": "Build a prototype to give the exact look and feel even before the actual software is developed",
#       "role": "Software Developer",
#       "node_id": 76
#     },
#     {
#       "task": "Identify relationships among classes",
#       "role": "Software Developer",
#       "node_id": 75
#     },
#     {
#       "task": "analyze specifications",
#       "role": "Software Developer",
#       "node_id": 74
#     },
#     {
#       "task": "add functionality",
#       "role": "Software Developer",
#       "node_id": 73
#     },
#     {
#       "task": "Add to the possible knowledge base of test estimation methods and estimation templates",
#       "role": "Software Developer",
#       "node_id": 72
#     },
#     {
#       "task": "Identify and analyze different types of cohesion",
#       "role": "Software Developer",
#       "node_id": 71
#     },
#     {
#       "task": "Validate the state\u2013transition diagrams drawn",
#       "role": "Software Developer",
#       "node_id": 70
#     },
#     {
#       "task": "Set up the de\ufb01ned modules or units",
#       "role": "Software Developer",
#       "node_id": 69
#     },
#     {
#       "task": "Fix changes necessary to make the system usable or comply to customer wishes",
#       "role": "Software Developer",
#       "node_id": 68
#     },
#     {
#       "task": "Test the product",
#       "role": "Software Developer",
#       "node_id": 67
#     },
#     {
#       "task": "Identify all the inputs and outputs",
#       "role": "Software Developer",
#       "node_id": 66
#     },
#     {
#       "task": "Construct data \ufb02ow diagrams showing functional dependencies",
#       "role": "Software Developer",
#       "node_id": 65
#     },
#     {
#       "task": "deliver changes in the customer environment",
#       "role": "Software Developer",
#       "node_id": 64
#     },
#     {
#       "task": "Create user object model diagram",
#       "role": "Software Developer",
#       "node_id": 63
#     },
#     {
#       "task": "Requirement Gathering and analysis",
#       "role": "Software Developer",
#       "node_id": 62
#     },
#     {
#       "task": "Implement forward engineering principles in software development",
#       "role": "Software Developer",
#       "node_id": 61
#     },
#     {
#       "task": "Use software estimation techniques for project estimation",
#       "role": "Software Developer",
#       "node_id": 60
#     },
#     {
#       "task": "operation and maintenance",
#       "role": "Software Developer",
#       "node_id": 59
#     },
#     {
#       "task": "Analyse the needs of the end user(s)",
#       "role": "Software Developer",
#       "node_id": 58
#     },
#     {
#       "task": "write code",
#       "role": "Software Developer",
#       "node_id": 57
#     },
#     {
#       "task": "understand customer requirements",
#       "role": "Software Developer",
#       "node_id": 56
#     },
#     {
#       "task": "Revise and enhance the Prototype",
#       "role": "Software Developer",
#       "node_id": 55
#     },
#     {
#       "task": "design system",
#       "role": "Software Developer",
#       "node_id": 54
#     },
#     {
#       "task": "Track and run the project",
#       "role": "Software Developer",
#       "node_id": 53
#     },
#     {
#       "task": "Carry out activities in each of the sub-phases",
#       "role": "Software Developer",
#       "node_id": 52
#     },
#     {
#       "task": "Identify the relationships among classes",
#       "role": "Software Developer",
#       "node_id": 2
#     },
#     {
#       "task": "Estimate testing activities",
#       "role": "Software Developer",
#       "node_id": 3
#     },
#     {
#       "task": "solve problems",
#       "role": "Software Developer",
#       "node_id": 4
#     },
#     {
#       "task": "test code",
#       "role": "Software Developer",
#       "node_id": 5
#     },
#     {
#       "task": "Test the complete system against initial requirements",
#       "role": "Software Developer",
#       "node_id": 6
#     },
#     {
#       "task": "Attempt to quantify software projects by using the size of the project to normalize other quality measures",
#       "role": "Software Developer",
#       "node_id": 7
#     },
#     {
#       "task": "Implement software",
#       "role": "Software Developer",
#       "node_id": 8
#     },
#     {
#       "task": "Participate in object-oriented analysis process",
#       "role": "Software Developer",
#       "node_id": 9
#     },
#     {
#       "task": "Design and implement modules with high functional cohesion and low coupling",
#       "role": "Software Developer",
#       "node_id": 10
#     },
#     {
#       "task": "reuse existing prototypes to build the actual system",
#       "role": "Software Developer",
#       "node_id": 11
#     },
#     {
#       "task": "troubleshooting",
#       "role": "Software Developer",
#       "node_id": 12
#     },
#     {
#       "task": "Describe the interfaces and interactions of the modules",
#       "role": "Software Developer",
#       "node_id": 13
#     },
#     {
#       "task": "Split up the software into its components",
#       "role": "Software Developer",
#       "node_id": 14
#     },
#     {
#       "task": "Define the functional contents of the modules",
#       "role": "Software Developer",
#       "node_id": 15
#     },
#     {
#       "task": "testing",
#       "role": "Software Developer",
#       "node_id": 16
#     },
#     {
#       "task": "produce working software",
#       "role": "Software Developer",
#       "node_id": 17
#     },
#     {
#       "task": "integrate all the available prototypes to form a complete system",
#       "role": "Software Developer",
#       "node_id": 18
#     },
#     {
#       "task": "Generate a Software Design Document",
#       "role": "Software Developer",
#       "node_id": 19
#     },
#     {
#       "task": "Check if all requirements are finalized",
#       "role": "Software Developer",
#       "node_id": 20
#     },
#     {
#       "task": "develop the system",
#       "role": "Software Developer",
#       "node_id": 21
#     },
#     {
#       "task": "Identify objects and group into classes",
#       "role": "Software Developer",
#       "node_id": 22
#     },
#     {
#       "task": "Develop systems that cannot be tampered by other parts of the system",
#       "role": "Software Developer",
#       "node_id": 23
#     },
#     {
#       "task": "complete a defined task",
#       "role": "Software Developer",
#       "node_id": 24
#     },
#     {
#       "task": "Developing the initial Prototype",
#       "role": "Software Developer",
#       "node_id": 25
#     },
#     {
#       "task": "Specify optimization criteria",
#       "role": "Software Developer",
#       "node_id": 26
#     },
#     {
#       "task": "accommodate changing requirements",
#       "role": "Software Developer",
#       "node_id": 27
#     },
#     {
#       "task": "Create dummy functions to act in place of other functions for testing",
#       "role": "Software Developer",
#       "node_id": 28
#     },
#     {
#       "task": "installation",
#       "role": "Software Developer",
#       "node_id": 29
#     },
#     {
#       "task": "build a prototype",
#       "role": "Software Developer",
#       "node_id": 30
#     },
#     {
#       "task": "Generate a System Architecture Document",
#       "role": "Software Developer",
#       "node_id": 31
#     },
#     {
#       "task": "Develop units independently",
#       "role": "Software Developer",
#       "node_id": 32
#     },
#     {
#       "task": "Review glossary",
#       "role": "Software Developer",
#       "node_id": 33
#     },
#     {
#       "task": "Maintenance",
#       "role": "Software Developer",
#       "node_id": 34
#     },
#     {
#       "task": "simulate data processing using a prototype services layer",
#       "role": "Software Developer",
#       "node_id": 35
#     },
#     {
#       "task": "Describe the various types of Coupling and Cohesion",
#       "role": "Software Developer",
#       "node_id": 36
#     },
#     {
#       "task": "release patches",
#       "role": "Software Developer",
#       "node_id": 37
#     },
#     {
#       "task": "transfer abstract of the program into code",
#       "role": "Software Developer",
#       "node_id": 38
#     },
#     {
#       "task": "concept",
#       "role": "Software Developer",
#       "node_id": 39
#     },
#     {
#       "task": "perform maintenance",
#       "role": "Software Developer",
#       "node_id": 40
#     },
#     {
#       "task": "Build from high-level models or concepts to lower-level details",
#       "role": "Software Developer",
#       "node_id": 41
#     },
#     {
#       "task": "Check requirements for validity and the possibility to implement them",
#       "role": "Software Developer",
#       "node_id": 42
#     },
#     {
#       "task": "Establish or update work products in each of the activities",
#       "role": "Software Developer",
#       "node_id": 43
#     },
#     {
#       "task": "implement and integrate services to the final prototype",
#       "role": "Software Developer",
#       "node_id": 44
#     },
#     {
#       "task": "develop a system",
#       "role": "Software Developer",
#       "node_id": 45
#     },
#     {
#       "task": "evaluate developer proposals and try them out before implementation",
#       "role": "Software Developer",
#       "node_id": 46
#     },
#     {
#       "task": "Decide whether to use prototyping based on the level of user interactions in the system",
#       "role": "Software Developer",
#       "node_id": 47
#     },
#     {
#       "task": "Define the operations that should be performed on the classes",
#       "role": "Software Developer",
#       "node_id": 48
#     },
#     {
#       "task": "Manage software complexity",
#       "role": "Software Developer",
#       "node_id": 49
#     },
#     {
#       "task": "Solve problems that did not arise during previous phases",
#       "role": "Software Developer",
#       "node_id": 50
#     }
#   ],
#   "Jane Smith": [
#     {
#       "task": "gather user feedback",
#       "role": "UX Designer",
#       "node_id": 152
#     },
#     {
#       "task": "design the system",
#       "role": "UX Designer",
#       "node_id": 151
#     },
#     {
#       "task": "Define the software components to meet the end user requirements and to meet the need of possible scalability of the system",
#       "role": "UX Designer",
#       "node_id": 150
#     },
#     {
#       "task": "Define the software components to meet the end user requirements and to meet the need of possible scalability of the system",
#       "role": "UX Designer",
#       "node_id": 98
#     },
#     {
#       "task": "Design the system",
#       "role": "UX Designer",
#       "node_id": 77
#     },
#     {
#       "task": "Design the system",
#       "role": "UX Designer",
#       "node_id": 149
#     },
#     {
#       "task": "evaluate developer proposals and try them out before implementation",
#       "role": "UX Designer",
#       "node_id": 148
#     },
#     {
#       "task": "evaluate developer proposals and try them out before implementation",
#       "role": "UX Designer",
#       "node_id": 46
#     },
#     {
#       "task": "Analyse the needs of the end user(s)",
#       "role": "UX Designer",
#       "node_id": 147
#     },
#     {
#       "task": "Analyse the needs of the end user(s)",
#       "role": "UX Designer",
#       "node_id": 58
#     },
#     {
#       "task": "Create a working model of the system to display to users",
#       "role": "UX Designer",
#       "node_id": 146
#     },
#     {
#       "task": "Increase user involvement in the product even before implementation",
#       "role": "UX Designer",
#       "node_id": 145
#     },
#     {
#       "task": "design a software prototype",
#       "role": "UX Designer",
#       "node_id": 121
#     },
#     {
#       "task": "design a software prototype",
#       "role": "UX Designer",
#       "node_id": 144
#     },
#     {
#       "task": "Review of the Prototype",
#       "role": "UX Designer",
#       "node_id": 143
#     },
#     {
#       "task": "understand customer requirements",
#       "role": "UX Designer",
#       "node_id": 56
#     },
#     {
#       "task": "understand customer requirements",
#       "role": "UX Designer",
#       "node_id": 142
#     },
#     {
#       "task": "Basic Requirement Identi\ufb01cation",
#       "role": "UX Designer",
#       "node_id": 141
#     },
#     {
#       "task": "Provide a better understanding of the system to users through a working model",
#       "role": "UX Designer",
#       "node_id": 140
#     },
#     {
#       "task": "Generate a Requirements Speci\ufb01cation Document",
#       "role": "UX Designer",
#       "node_id": 130
#     },
#     {
#       "task": "Generate a Requirements Speci\ufb01cation Document",
#       "role": "UX Designer",
#       "node_id": 139
#     },
#     {
#       "task": "Check requirements for validity and the possibility to implement them",
#       "role": "UX Designer",
#       "node_id": 138
#     },
#     {
#       "task": "Check requirements for validity and the possibility to implement them",
#       "role": "UX Designer",
#       "node_id": 42
#     },
#     {
#       "task": "understand about what exactly is expected from the product under development",
#       "role": "UX Designer",
#       "node_id": 137
#     },
#     {
#       "task": "understand about what exactly is expected from the product under development",
#       "role": "UX Designer",
#       "node_id": 81
#     },
#     {
#       "task": "identify confusing or difficult functions",
#       "role": "UX Designer",
#       "node_id": 136
#     }
#   ]
# }

# %%
# Test node update
print("\nUpdating node...")
update_result = update_node(
    test_workspace,
    "1",  # example node ID
    "Some Task",  # example node name
    {"priority": "high"}
)
print("Update result:", update_result)
# Out:
# Updating node...
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 3, column: 39, offset: 49} for query: '\n                MATCH (n)\n                WHERE ID(n) = $node_id AND n.name = $node_name\n                SET n += $properties\n            '
# Update result: {'status': 'success', 'message': 'Node Some Task updated'}

# %%
    
# Test node deletion
print("\nDeleting node...")
delete_result = delete_node(
    test_workspace,
    "1",  # example node ID
    "Some Task"  # example node name
)
print("Delete result:", delete_result)
# Out:
# Deleting node...
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 3, column: 39, offset: 49} for query: '\n                MATCH (n)\n                WHERE ID(n) = $node_id AND n.name = $node_name\n                DETACH DELETE n\n            '
# Delete result: {'status': 'success', 'message': 'Node Some Task deleted'}
